# %%
import os
import pandas as pd
import googleapiclient.discovery
import re
import time

# API Key 설정
API_KEY = "AIzaSyB2SkQGbABMxMcxthawNXVkPIu9xyWtRYE"  # 자신의 유효한 API 키를 입력하세요
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# 유튜브 클라이언트 초기화
youtube = googleapiclient.discovery.build(
    YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY
)

# 한글 확인 함수
def contains_korean(text):
    """
    텍스트에 한글이 포함되어 있는지 확인
    """
    return bool(re.search(r"[가-힣]", text))

# Shorts 동영상 검색 (한국 지역)
def search_shorts_videos(region_code="KR", video_category_id=None, max_results=100):
    """
    제목에 한글이 포함된 한국 숏츠 동영상 검색
    """
    videos = []
    next_page_token = None

    while len(videos) < max_results:
        try:
            request = youtube.videos().list(
                part="snippet,contentDetails",
                chart="mostPopular",
                regionCode=region_code,  # 한국 지역 설정
                videoCategoryId=video_category_id,  # 특정 카테고리 (예: 음악, 엔터테인먼트)
                maxResults=50,  # 요청당 최대 50개
                pageToken=next_page_token
            )
            response = request.execute()

            for item in response.get("items", []):
                title = item["snippet"]["title"]
                duration = item["contentDetails"]["duration"]  # 동영상 길이
                if contains_korean(title) and is_short_video(duration):
                    video_id = item["id"]
                    description = item["snippet"].get("description", "")
                    channel = item["snippet"]["channelTitle"]

                    videos.append({
                        "video_id": video_id,
                        "title": title,
                        "channel": channel,
                        "description": description
                    })

            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break
        except Exception as e:
            print(f"Shorts 동영상 검색 중 오류 발생: {e}")
            break

    return videos[:max_results]

# 동영상 길이 확인 함수
def is_short_video(duration):
    """
    ISO 8601 형식의 동영상 길이를 분석하여 Shorts (60초 이하)인지 확인
    """
    match = re.match(r"PT(\d+M)?(\d+S)?", duration)
    if match:
        minutes = int(match.group(1)[:-1]) if match.group(1) else 0
        seconds = int(match.group(2)[:-1]) if match.group(2) else 0
        return (minutes * 60 + seconds) <= 60
    return False

# 댓글 수집
def get_video_comments(video_id, max_comments=1000):
    """
    특정 유튜브 동영상의 댓글 가져오기
    """
    comments = []
    next_page_token = None

    while len(comments) < max_comments:
        try:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token
            )
            response = request.execute()

            for item in response.get("items", []):
                comment = item["snippet"]["topLevelComment"]["snippet"]
                replies = item.get("replies", {}).get("comments", [])

                comments.append({
                    "author": comment["authorDisplayName"],
                    "comment": comment["textDisplay"],
                    "is_reply": False,
                    "reply_to": None
                })

                for reply in replies:
                    comments.append({
                        "author": reply["snippet"]["authorDisplayName"],
                        "comment": reply["snippet"]["textDisplay"],
                        "is_reply": True,
                        "reply_to": comment["authorDisplayName"]
                    })

            next_page_token = response.get("nextPageToken")
            if not next_page_token:
                break
        except Exception as e:
            print(f"댓글 가져오기 중 오류 발생(video_id: {video_id}): {e}")
            break

    return comments[:max_comments]

# 동영상 정보 저장
def process_and_save_videos(videos, output_path="shorts_data_korean/videos.csv"):
    """
    동영상 정보를 CSV로 저장
    """
    df = pd.DataFrame(videos)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    df.to_csv(output_path, index=False)
    print(f"동영상 정보 저장 완료: {output_path}")
    return videos

# 댓글 분석 및 저장
def analyze_and_save_comments(video_id, output_dir="shorts_data_korean/comments"):
    """
    댓글을 수집하고 CSV로 저장
    """
    os.makedirs(output_dir, exist_ok=True)
    comments = get_video_comments(video_id, max_comments=1000)
    comments_df = pd.DataFrame(comments)

    if not comments_df.empty:
        output_path = os.path.join(output_dir, f"{video_id}_comments.csv")
        comments_df.to_csv(output_path, index=False)
        print(f"댓글 저장 완료: {output_path}")
    else:
        print(f"댓글이 없습니다(video_id: {video_id}).")

# 전체 처리
def process_korean_shorts_videos():
    """
    제목에 한글이 포함된 한국 숏츠 동영상 댓글 수집 및 저장
    """
    output_dir = "shorts_data_korean"

    # Shorts 동영상 검색 (카테고리 ID: 예시로 엔터테인먼트 ID "24" 사용)
    videos = search_shorts_videos(region_code="KR", video_category_id="24", max_results=100)
    process_and_save_videos(videos, output_path=os.path.join(output_dir, "videos.csv"))

    # 댓글 수집
    for video in videos:
        analyze_and_save_comments(video["video_id"], output_dir=os.path.join(output_dir, "comments"))
        time.sleep(1)  # API 요청 제한 보호

# 실행
process_korean_shorts_videos()
# Out:
# 동영상 정보 저장 완료: shorts_data_korean/videos.csv
# 댓글 저장 완료: shorts_data_korean/comments/12Zm3pR9QQU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/UCzUbLjC39E_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/BdQ9JI71fCs_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/U7h4-IaJ3Qk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/X3izrvadxyM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/mgXOhclAfgo_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/LJdStk8ZafM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/EVDKew_iLnw_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/HkbyZ1BJC_E_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/bRaqFEBwh_0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/MDF4HnkI9AU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/O0nrfZxxvNQ_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/OW3i23kxB78_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/WaUcenPAtqM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/tCJkIXkWQyI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/0zVT42FHdU4_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/ESnU9nVKXO0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/X2IiYr7ER6k_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/6SUlZhje-rE_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/2qsd9b2CUoc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/jR_KNv3GiTM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/qXwpkrOsaOE_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/-9SV7IBMQ4U_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/KBFvaXifZek_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/XH9S3uaPBTU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/w7IIS2kJwv8_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/-V_aZpqTXdE_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/pKz997xa3Wk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/nb-KpoWIS1Q_comments.csv
# 댓글 가져오기 중 오류 발생(video_id: uq2qZa2M_EM): <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet%2Creplies&videoId=uq2qZa2M_EM&maxResults=100&key=AIzaSyB2SkQGbABMxMcxthawNXVkPIu9xyWtRYE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# 댓글이 없습니다(video_id: uq2qZa2M_EM).
# 댓글 저장 완료: shorts_data_korean/comments/jRrTh3mM5gw_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/Sgyg2zqzNDs_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/4i13ln-oHtk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/PyNsQ4uXj5E_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/OA-e0xYjZ-k_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/daUpxErcnYQ_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/KQ5FWEW6_N0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/B3zt4ddsBBc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/_2SJw9ekl5A_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/zJcJHxwX9ys_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/m4-orYu8dtM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/1LPx4_x73jI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/M4dmevGmoR4_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/8jR7Z14GW-I_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/Nwads3-b5Nc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/1wNS7SDDOrI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/2yoAcGRm7f0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/9U35_-oYJrc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/UySCCI3hWcY_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/n_JDb_apwMw_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/whx1YzRVc9U_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/-i_JF8wDgOg_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/InI9Tbwr0VA_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/WFi4GR1p4X0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/zLUgxJGqlOk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/v-f5-h5bQfI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/AifkDhtk8kE_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/s6Ijh9The90_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/K3GGj7MK4C4_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/HqFtw8oWUNY_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/wJM_CbqhxRM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/5a-DEeFz09o_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/8MZFQMstCSI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/ORvWV6x3poM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/yl1FrGVvYTM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/8MOPHx2uVEI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/kuFfiI5De6g_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/nfvco1Lu8zM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/qa3reoBjgHI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/AbIqVhdpCQc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/XIm5a9ggRo8_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/qxDViMAcsKQ_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/4Iv5vkaYN4o_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/RBOEYnW3P40_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/Kuwu3-9eGkc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/1ySAJ6fX0m8_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/VnCmyZlUIJ0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/XK_WR60dyPk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/UP91Q2zPdsc_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/NT6PsmjXlAk_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/YQ9SyZCPt6A_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/r2n9HOo_M5U_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/2lC8dUujF2s_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/zfzvePfTttU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/8HPy6bIUDXQ_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/xqFeDOzmRmM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/VE4QnVTvIGI_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/6W-Eqd2kC4Q_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/ngAwRwXlcGw_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/JSORZ3hqBWU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/clwSgIwt4qg_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/WU0G0jbdryw_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/xIKpxGegA6I_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/ZHLfjl7KnsM_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/dG9OKEGI6f4_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/_w44l76tSlY_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/13AwQyf5Aw0_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/lXiiaw2cQxU_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/OGSHRbVPA-A_comments.csv
# 댓글 저장 완료: shorts_data_korean/comments/f3VO3U2t5IE_comments.csv

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# 스팸 패턴 정의
SPAM_PATTERNS = [
    r"(클릭|이름|프로필|보러가기|링크|구독|프사|채널)",
    r"9금",  # "I9" 또는 "19" 관련
]

def is_korean(text):
    """
    텍스트가 한글인지 확인하는 함수
    """
    return bool(re.search(r"[가-힣]", text))

def find_similar_comments(comments, threshold=0.8):
    """
    댓글 간 유사도 분석
    """
    if len(comments) < 2:
        return []

    vectorizer = TfidfVectorizer(stop_words="english")
    tfidf_matrix = vectorizer.fit_transform(comments)
    similarity_matrix = cosine_similarity(tfidf_matrix)

    similar_pairs = []
    n_comments = len(comments)

    for i in range(n_comments):
        for j in range(i + 1, n_comments):
            if similarity_matrix[i, j] >= threshold:
                similar_pairs.append((i, j))
    return similar_pairs

def detect_spam_with_replies(comments_df):
    """
    스팸 댓글 탐지 (영어 제외, 대댓글이 2개 이상인 경우 + "I9" 또는 "19" 작성자 조건 추가)
    """
    # 대댓글 개수 계산
    comments_df["reply_count"] = comments_df.groupby("reply_to")["reply_to"].transform("count")
    comments_df["reply_count"] = comments_df["reply_count"].fillna(0)

    # "I9" 또는 "19"를 포함한 작성자 필터링
    i9_indices = comments_df[comments_df["author"].str.contains("9금", na=False)].index

    similar_comments = find_similar_comments(comments_df["comment"].tolist())
    spam_indices = set(i9_indices)  # 초기 스팸 인덱스에 추가

    for i, j in similar_comments:
        if comments_df.iloc[j]["is_reply"]:
            comment_text = comments_df.iloc[j]["comment"]
            if is_korean(comment_text) and comments_df.iloc[j]["reply_count"] >= 2:
                for pattern in SPAM_PATTERNS:
                    if re.search(pattern, comment_text):
                        spam_indices.add(j)

    comments_df["is_spam"] = comments_df.index.isin(spam_indices).astype(int)
    return comments_df

def classify_and_save_comments_with_replies(input_dir="shorts_data_korean/comments", output_dir="shorts_data_korean/spam_classified"):
    """
    저장된 댓글들을 읽어와 영어 댓글 제외 및 대댓글 조건으로 스팸 여부를 분류하고 저장
    """
    os.makedirs(output_dir, exist_ok=True)
    for filename in os.listdir(input_dir):
        if filename.endswith(".csv"):
            file_path = os.path.join(input_dir, filename)
            try:
                comments_df = pd.read_csv(file_path)

                if not comments_df.empty:
                    classified_df = detect_spam_with_replies(comments_df)
                    output_file_path = os.path.join(output_dir, filename)
                    classified_df.to_csv(output_file_path, index=False)
                    print(f"스팸 분류 완료 및 저장: {output_file_path}")
                else:
                    print(f"빈 파일입니다: {file_path}")
            except Exception as e:
                print(f"파일 처리 중 오류 발생: {file_path} - {e}")

# 실행
classify_and_save_comments_with_replies()
# Out:
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/qxDViMAcsKQ_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/UP91Q2zPdsc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/WaUcenPAtqM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/-V_aZpqTXdE_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/Kuwu3-9eGkc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/B3zt4ddsBBc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/8jR7Z14GW-I_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/zJcJHxwX9ys_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/5a-DEeFz09o_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/whx1YzRVc9U_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/_w44l76tSlY_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/9U35_-oYJrc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/WFi4GR1p4X0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/nfvco1Lu8zM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/LJdStk8ZafM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/ZHLfjl7KnsM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/lXiiaw2cQxU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/xqFeDOzmRmM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/v-f5-h5bQfI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/BdQ9JI71fCs_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/XH9S3uaPBTU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/bRaqFEBwh_0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/AifkDhtk8kE_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/jR_KNv3GiTM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/U7h4-IaJ3Qk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/mgXOhclAfgo_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/dG9OKEGI6f4_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/m4-orYu8dtM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/UySCCI3hWcY_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/nb-KpoWIS1Q_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/NT6PsmjXlAk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/OGSHRbVPA-A_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/qXwpkrOsaOE_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/6W-Eqd2kC4Q_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/JSORZ3hqBWU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/PyNsQ4uXj5E_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/8MOPHx2uVEI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/OA-e0xYjZ-k_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/InI9Tbwr0VA_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/X3izrvadxyM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/UCzUbLjC39E_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/wJM_CbqhxRM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/2yoAcGRm7f0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/_2SJw9ekl5A_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/WU0G0jbdryw_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/xIKpxGegA6I_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/zLUgxJGqlOk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/s6Ijh9The90_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/13AwQyf5Aw0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/daUpxErcnYQ_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/-i_JF8wDgOg_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/12Zm3pR9QQU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/4Iv5vkaYN4o_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/XK_WR60dyPk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/qa3reoBjgHI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/X2IiYr7ER6k_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/EVDKew_iLnw_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/6SUlZhje-rE_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/2qsd9b2CUoc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/VnCmyZlUIJ0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/O0nrfZxxvNQ_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/AbIqVhdpCQc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/ESnU9nVKXO0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/r2n9HOo_M5U_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/tCJkIXkWQyI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/YQ9SyZCPt6A_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/ORvWV6x3poM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/KQ5FWEW6_N0_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/MDF4HnkI9AU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/1wNS7SDDOrI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/zfzvePfTttU_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/f3VO3U2t5IE_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/kuFfiI5De6g_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/HqFtw8oWUNY_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/K3GGj7MK4C4_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/1ySAJ6fX0m8_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/-9SV7IBMQ4U_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/pKz997xa3Wk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/Sgyg2zqzNDs_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/n_JDb_apwMw_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/0zVT42FHdU4_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/2lC8dUujF2s_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/VE4QnVTvIGI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/RBOEYnW3P40_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/clwSgIwt4qg_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/8MZFQMstCSI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/1LPx4_x73jI_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/w7IIS2kJwv8_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/yl1FrGVvYTM_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/KBFvaXifZek_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/8HPy6bIUDXQ_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/4i13ln-oHtk_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/XIm5a9ggRo8_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/ngAwRwXlcGw_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/HkbyZ1BJC_E_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/jRrTh3mM5gw_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/M4dmevGmoR4_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/Nwads3-b5Nc_comments.csv
# 스팸 분류 완료 및 저장: shorts_data_korean/spam_classified/OW3i23kxB78_comments.csv

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 로드
def load_spam_data(input_dir="shorts_data_korean/spam_classified"):
    """
    분류된 스팸 데이터를 로드하고 병합
    """
    all_files = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if f.endswith(".csv")]
    dataframes = []
    
    for file in all_files:
        try:
            df = pd.read_csv(file)
            df["video_id"] = os.path.basename(file).replace("_comments.csv", "")
            dataframes.append(df)
        except Exception as e:
            print(f"파일 로드 오류: {file} - {e}")
    
    return pd.concat(dataframes, ignore_index=True) if dataframes else pd.DataFrame()

# 데이터 로드
df = load_spam_data()
print(f"전체 데이터 로드 완료. 총 {len(df)}개의 댓글이 로드되었습니다.")
# Out:
# 전체 데이터 로드 완료. 총 38705개의 댓글이 로드되었습니다.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

# mpl.rcParams['font.family'] = 'Malgun Gothic' # Windows
mpl.rcParams['font.family'] = 'AppleGothic' # Mac
mpl.rcParams['axes.unicode_minus'] = False

# %%
def visualize_spam_vs_ham_from_classified(input_dir="shorts_data_korean/spam_classified"):
    """
    스팸 vs 정상 댓글 비율을 `spam_classified` 데이터에서 확인하여 시각화
    """
    # 스팸 및 정상 댓글 개수 초기화
    spam_count = 0
    ham_count = 0

    # 분류된 데이터에서 스팸과 정상 댓글 집계
    for filename in os.listdir(input_dir):
        if filename.endswith(".csv"):
            file_path = os.path.join(input_dir, filename)
            try:
                df = pd.read_csv(file_path)

                if "is_spam" in df.columns:
                    spam_count += df[df["is_spam"] == 1].shape[0]
                    ham_count += df[df["is_spam"] == 0].shape[0]
            except Exception as e:
                print(f"파일 처리 중 오류 발생: {file_path} - {e}")

    # 비율 계산
    total = spam_count + ham_count
    if total == 0:
        print("데이터가 비어 있어 비율을 계산할 수 없습니다.")
        return

    labels = ["Ham (정상)", "Spam (스팸)"]
    sizes = [ham_count, spam_count]

    print(f"정상 댓글 수: {ham_count}, 스팸 댓글 수: {spam_count}")
    print(f"스팸 비율: {spam_count / total * 100:.2f}%")

    # 파이 차트 시각화
    plt.figure(figsize=(8, 6))
    plt.pie(
        sizes,
        labels=labels,
        autopct='%1.1f%%',
        startangle=140,
        colors=["green", "red"]
    )
    plt.title("스팸 vs 정상 댓글 비율 (Spam Classified)")
    plt.show()

# 실행
visualize_spam_vs_ham_from_classified()
# Out:
# 정상 댓글 수: 38689, 스팸 댓글 수: 16
# 스팸 비율: 0.04%

# %%
# 동영상별 스팸 비율
video_spam_ratio = df.groupby("video_id")["is_spam"].mean().reset_index()
video_spam_ratio.columns = ["video_id", "spam_ratio"]
video_spam_ratio = video_spam_ratio.sort_values("spam_ratio", ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(
    data=video_spam_ratio.head(20),
    x="spam_ratio",
    y="video_id",
    palette="Reds_r"
)
plt.xlabel("스팸 비율")
plt.ylabel("동영상 ID")
plt.title("스팸 비율 상위 20개 동영상")
plt.show()
# Out:
# /var/folders/r8/b4bk9xvj52d2prxx0pm4qz8m0000gn/T/ipykernel_22329/282944486.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# 댓글 길이 계산 및 분포
df["comment_length"] = df["comment"].str.len()

plt.figure(figsize=(10, 6))
sns.histplot(
    data=df,
    x="comment_length",
    hue="is_spam",
    kde=True,
    palette={0: "blue", 1: "red"},
    bins=30
)
plt.xlabel("댓글 길이")
plt.ylabel("댓글 수")
plt.title("댓글 길이 분포 (스팸 vs 정상)")
plt.show()

# %%
# 대댓글 여부 분석
reply_counts = df["is_reply"].value_counts()
reply_labels = ["Top-level (최상위)", "Reply (대댓글)"]

plt.figure(figsize=(8, 6))
plt.pie(
    reply_counts,
    labels=reply_labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=["orange", "purple"]
)
plt.title("최상위 댓글 vs 대댓글 비율")
plt.show()

# %%
# "9금" 패턴 포함 댓글 비율
i9_comments = df[df["author"].str.contains("9금", na=False)]
i9_ratio = len(i9_comments) / len(df)

print(f'"9금" 관련 댓글 비율: {i9_ratio:.2%}')

# 시각화
plt.figure(figsize=(6, 6))
plt.bar(["9금 관련 댓글", "기타"], [len(i9_comments), len(df) - len(i9_comments)], color=["red", "blue"])
plt.ylabel("댓글 수")
plt.title('"9금" 관련 댓글 비율')
plt.show()
# Out:
# "9금" 관련 댓글 비율: 0.03%
